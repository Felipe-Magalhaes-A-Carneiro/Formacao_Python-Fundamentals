# %% [markdown]
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# # ***A Programação Orientada a Objetos (POO)***

# %% [markdown]
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# É um paradigma de programação que organiza o código em "objetos" que combinam dados (características) e comportamentos (ações).
#
# Imagine que você está criando um jogo. Em vez de ter variáveis soltas para vida_heroi, forca_heroi e funções como atacar(personagem), você cria um molde chamado Guerreiro que já contém tudo isso.

# %% [markdown]
# Para explicarmos esse importantíssimo paradigma de criação orientada a objetos é interessante utilizarmos o termo ***COMERN*** :
#
# - ***Confiável*** - O isolamento entre as partes gera algo mais seguro. Ao alterar uma das partes, nenhuma outra é afetada.
#
# - ***Oportuno*** - Ao dividir tudo em partes, cada uma delas pode ser desenvolvida em paralelo.
#
# No exemplo do carro, eu não preciso produzir o farol primeiro para depois produzir o voltante, não. Isso pode ser feito tudo ao mesmo tempo.
#
# Apenas na hora da montagem, é necessário uma ordem. Não podemos coloar o banco antes de pintar, se não o banco vai ser pintado junto com o carro.
#
# - ***Manutenível*** - Atualizar é mais fácil. Uma pequena alteração vai beneficiar todas as partes relacionadas.
#
# - ***Extensiavel*** - Um sistema não deve ser estático. Tudo deve mudar e crescer para mermanecer útil.
#
# - ***Reutilizavel*** - Objetos que goram criados para um sistema podem ser aproveitados em outros sistemas.
#
# - ***Natural*** - Mais fácil de atender. Maior atenção às funcionalidades do que aos detalhes de implementação.
#
# Essas são as vantagens de se usar POO. É fundamental para o dia de hoje.

# %% [markdown]
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ## ***1. Os Quatro Pilares da POO***
# Para dominar a POO, você precisa entender estes quatro conceitos fundamentais:
#
# ### A. Abstração
# É simplificar um objeto real para o que importa no seu sistema.
#
# - Exemplo: Para um sistema bancário, um "Cliente" precisa de nome e CPF. Para um hospital, ele precisa de tipo sanguíneo. A abstração filtra o que é irrelevante.
#
# ### B. Encapsulamento
# É "esconder" os detalhes internos de como um objeto funciona e proteger seus dados. Em Python, usamos um prefixo de sublinhado (_ ou __) para indicar que algo é privado.
#
# - Exemplo: Você não mexe direto nas engrenagens de um relógio; você usa os botões externos (métodos) para ajustar a hora.
#
# ### C. Herança
# Permite que uma classe (Filha) herde atributos e métodos de outra (Pai), evitando repetição de código.
#
# - Exemplo: Uma classe Carro e uma classe Moto podem herdar de uma classe Veiculo.
#
# ### D. Polimorfismo
# É a capacidade de diferentes classes responderem à mesma mensagem de formas diferentes.
#
# - Exemplo: Tanto Cachorro quanto Gato têm o método falar(), mas um faz "Au" e o outro "Miau".

# %% [markdown]
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ## ***1.1 Mas o que é o que em programação Orientada a objeto?***
#
# Primeiramente, para facilitar a sua vida, precisamos saber o que é uma classe primeiro, logo:
#
# ### ***O que é um classe?***
# Classe nada mais é do que uma forma, como de um biscoito que você a utiliza para poder fazer vários biscoitos.
# Além disso, se quiser, pode fazer biscoitos com ***atributos*** diferentes (chocolate, morango e etc), mas que todos serão afetados com as mesmas ***funções*** (cozinhar(), esquentar(), comer() e etc).
#
# Continuando com o exemplo dos biscoitos:
# Imagine que você queira fazer biscoitos, eles possuiram o mesmo formato de coração, mas não o mesmo sabor.
#
# Como você faria?
#
# Bom, você primeiro usaria uma forma de biscoitos de coração, para que assim, todos eles tenham os ***'atributos' (ou 'caracteristicas')*** iguais (ser de coração, mas de morango. ou ser de coração, mas de chocolate). E não só isso, os biscoitos terão também as suas ***'funcões' (ou 'comportamentos')*** que cada biscotio irá sofrer, graças ao fato delas virem da mesma forma de biscoito (cozinhar).
#
# ### ***O que é um objeto?***
#
# Objetos são uma evolução das variáveis. Elas além de guardarem dados, podem executar funcionalidades. Então, sim, Objetos são variáveis (a sua criação ocorre do mesmo jeito), além de guardar dados, podem fazer coisas com esses dados.
#
# Objeto é nada mais é do que algo que é feito com base na classe (forma) utilizada. Em outras palavras, um objeto é uma ***instancia*** de uma classe.
#
#
# ### ***Instanciação da Classe***
#
# 'Instanciar' (Como um verbo) é o termo técnico correto no meio profissional, utilize-o.
#
# - Quando você você diz:
# "Vou instanciar a classe tal..."
#
# - Então, você quer dizer:
# "Vou criar um objeto com a classe tal..."
#
# Quando estamos instanciando, estamos no fim das contas, chamando um método especial chamado "Método construtor" (Veja mais na próxima cartilha em: [09-03-POO-construtores_e_destrutores](09-03-POO-construtores_e_destrutores.ipynb)) que nada mais é do que um método que chamo ao construir um objeto, esse contrutor é o _ _ init _ _(self).
#
# ### ***Exemplo de uma declaração de classe:***
#
# ![declaracao_da_classe_exemplo.png](attachment:declaracao_da_classe_exemplo.png)
#
#
#
# ***Exemplo que ocorre o "instanciar" de uma classe:***
#
#         obj = MinhaClasse()
#
# "MinhaClasse" esta com " () " ao lado. É aqui que ocorre a instanciação de uma classe. Entendo que pode confundir com funções, já que é assim que chamamos uma função, mas quando vamos instanciar é assim que fazemos; ela é armazenada dentro de um objeto que aqui achei de "obj"
#
#
#
#
# ### ***Para concluir o conceito de Objeto:***
#
# "***OBJETO*** - Coisa ***material*** ou ***abstrata*** que é feita a partir de um ***modelo*** e pode ser descrita por meio dos seus ***'atributos' (ou 'caracteristicas')***, ***'funcões' (ou 'comportamentos')*** e ***estado*** atual".
#
# ### ***Existêm 2 tpos de objeto:***
#
#
# ### 1º Tipo: Material
# Existe no mundo real:
# - caneta;
# - livro;
# - copo;
# - veículo;
# - e etc.
#
# ### 2º Tipo: Abstrata
# Naõ existe no mundo real, mas no campo das ideias e do conceito:
# - 'Consulta' marcada no médico (sabemos que não podemos pegar em uma 'consulta', mas esse conceito tem significado intricico e de valor que atribuímos a ele.)
#         Seus atributos são: 'hora da consulta', 'médico que irá atender', ';
# - Processo de venda: devolução, horário da compra, quem comprou, dados da venda... tudo isso são métodos;
# - Compromisso com uma reunião: horário, com quem, onde fica, qual o tema, começou?, atrasou? resolveu o problema?.
# - aula de faculdade;
# - transação brancaria;
# - reserva de passagem aérea;
# - Um erro de sistema: quando houve, seu 'estado', como objeto,
# - clientes;
# - alunos

# %% [markdown]
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ## ***1.2 E o que seria o 'estado' de um objeto?***
#
# O estado é um conjunto de todos os valores de atributos que um objeto tem, em um determinado 'momento'.
# Ou seja, seguindo o exemplo dos biscoitos, imagine que:
#
#     biscoito_pistache = Biscoito(
#         tamanho = 8.2
#         massa = baunilha
#         peso = 54.3
#         cobertura = pistache
#         cozido = True
#         temperadutra = 55, " °C"
#     )
#
# Ou seja, isso é um 'estado', é a forma em que ele se encontra no momento. E, nesse momento ele é:
# biscoito_pistache que tem tamanho = 8.2cm; massa = baunilha; peso = 54.3g e etc...
#
# Peguemos o atributo 'atributo' 'temperatura, por exemplo:
#
# Como o nosso 'biscoito_pistache' pode estar assim na hora de termos criado-o, mas pela lógica do exemplo que o objeto segue, sabemos que a temperatura de um biscoito muda com o tempo. Ele pode estar 55°C, mas isso mudará ao longo do tempo para menos.
#
# Podemos literalmente mudar o atributo temperatura ao longo do nosso código.
#
# Logo, o estado do 'biscoito_pistache' não é mais o que era antes.

# %% [markdown]
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ## ***2. A Anatomia de uma Classe em Python***
# Vamos construir uma classe que aplique esses conceitos:

# %%
class Veiculo: # Classe Pai
    # caracteristicas:
    def __init__(self, marca, modelo):
        self.marca = marca
        self.modelo = modelo
        self._ligado = False # Encapsulamento (privado por convenção)

    # atributos:
    def ligar(self):
        self._ligado = True
        print(f"{self.modelo} ligou.")

class Carro(Veiculo): # Herança: Carro herda de Veiculo
    def mover(self): # Método específico
        if self._ligado:
            print(f"O carro {self.modelo} está andando.")
        else:
            print("Ligue o carro primeiro!")

class Aviao(Veiculo):
    def mover(self): # Polimorfismo: mover() aqui é voar
        print(f"O avião {self.modelo} está decolando!")

# %%
#instanciando objeto utilizando a classe Veiculo
moto = Veiculo("Honda", "CG 160")

# %%
moto.ligar()
# Out:
# CG 160 ligou.

# %%
#instanciando objeto utilizando a classe Carro que por ter Herdado de Veiculos ele pode ligar()
carro = Carro("Fiat", "Palio")

# %%
carro.ligar() # Utilizando algo da classe Veiculo
carro.mover() # Utilizando algo da classe Carro
# Out:
# Palio ligou.
# O carro Palio está andando.

# %%
#instanciando objeto utilizando a classe Aviao que por ter Herdado de Veiculos ele pode ligar() e mover()
aviao = Aviao("Airbus", "A350 (900/1000)")

# %%
aviao.ligar() # Utilizando algo da classe Veiculo
aviao.mover() # Utilizando algo da classe Carro, mas que por polimorfismo, mudamos o que mover() retorna
# Out:
# A350 (900/1000) ligou.
# O avião A350 (900/1000) está decolando!

# %% [markdown]
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# # ***3. O Método Mágico _ _str_ _***
#
# Lembra que falamos que tudo em Python é praticamente um objeto? Quando você dá um print(objeto), o Python procura o método __str__ para saber como exibir aquele objeto em texto.

# %%
class Livro:
    def __init__(self, titulo, autor):
        self.titulo = titulo
        self.autor = autor

    def __str__(self):
        return f"'{self.titulo}' por {self.autor}"

meu_livro = Livro("Dom Casmurro", "Machado de Assis")
print(meu_livro) # Saída: 'Dom Casmurro' por Machado de Assis
# Out:
# 'Dom Casmurro' por Machado de Assis

# %% [markdown]
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# # ***4. Diferença entre Classe e Instância***
# - Classe: É o molde (ex: Receita de Bolo).
#
# - Instância (Objeto): É o que sai do molde (ex: O bolo de chocolate que está na mesa).

# %% [markdown]
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# # ***5. Quando usar POO?***
# - Quando seu projeto começa a ficar grande e complexo.
#
# - Quando você tem muitas funções que operam sobre os mesmos dados.
#
# - Quando você precisa criar múltiplos "seres" que se comportam de forma parecida (usuários, produtos, inimigos em um jogo).

# %% [markdown]
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# # ***O que é 'self'?***
#
# É uma referencia ao objeto, chamamos de 'referência explícita'.
#
# O self é, sem dúvida, o conceito que mais confunde quem está começando em POO, mas a explicação é mais simples do que parece: ***o self é o nome que o objeto usa para se referir a si mesmo***.
#
# Imagine que você tem uma fábrica de carros (a Classe). Quando um carro sai da linha de montagem (o Objeto), ele precisa de uma forma de saber qual é a sua própria cor, sem confundir com a cor do carro que saiu antes dele.

# %% [markdown]
# # ***1. Por que o self é necessário?***
#
# O Python não "mágica" os atributos para dentro do objeto. Quando você define um método, o Python envia automaticamente o próprio objeto como o primeiro argumento. O self é o "balde" que recebe esse objeto.
#
# Veja a diferença:

# %%
class Celular:
    def __init__(self, marca, modelo):
        # "Neste objeto específico (self), guarde esta marca"
        self.marca = marca 
        self.modelo = modelo

    def ligar(self):
        # Sem o self, o Python não saberia DE QUEM é esse modelo
        print(f"O {self.modelo} está ligando...")

# Criando instâncias (objetos)
meu_celular = Celular("Apple", "iPhone 15")
seu_celular = Celular("Samsung", "S24")

meu_celular.ligar() # Saída: O iPhone 15 está ligando...
seu_celular.ligar() # Saída: O S24 está ligando...
# Out:
# O iPhone 15 está ligando...
# O S24 está ligando...

# %% [markdown]
# # ***2. O que acontece "por baixo dos panos"?***
#
# Quando você chama meu_celular.ligar(), o Python traduz isso internamente para:
# Celular.ligar(meu_celular)
#
# O objeto meu_celular entra no lugar do parâmetro self. É por isso que, embora você defina o método com self, você não passa nada para ele na hora de chamar a função.

# %% [markdown]
# # ***3. O self é obrigatório?***
#
# - O nome self: Não é uma palavra-chave protegida. Você poderia usar banana ou eu, e o código funcionaria. Mas ***99,9% dos programadores Python usam*** self. Usar outro nome é como dirigir do lado errado da pista: você pode até conseguir, mas vai causar um acidente na leitura do código.
#
# - ***A presença do parâmetro***: Sim, é obrigatória para métodos de instância. Se você esquecer o self na definição:
# def ligar(): print("Oi")
#
# E tentar chamar meu_celular.ligar(), o Python vai dar um erro dizendo que você passou 1 argumento, mas a função aceita 0.

# %% [markdown]
# # ***4. Analogia do Crachá***
#
# Pense no 'self' como um crachá.
#
# - A classe é o manual de instruções da empresa.
#
# - O objeto é o funcionário.
#
# - O self é o funcionário olhando para o próprio crachá para dizer: "Eu sou o funcionário número 42 e meu departamento é Vendas".

# %% [markdown]
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# # ***Como saber o que há dentro de uma instância?***

# %% [markdown]
# Sabemos que, uma vez bem definida a Classe, podemos colocar o objeto que recebe suas propriedades dentro de uma variável, esse processo é chamdo de "Instanciar".
#
# Suponhamos que em um longo código, eu precise saber, naquele momento quais são os valores que aquela instancia possuí, uma vez que ela já tenha sido criada ha algum tempo:
#
# Utilizamos o método _ _str_ _()

# %% [markdown]
# # _ _str_ _()
#
# Ele aceita retornar (com o return) qualquer valor string.

# %%
class Celular:
    def __init__(self, marca, modelo):
        
        self.marca = marca 
        self.modelo = modelo

    def ligar(self):
        print(f"O {self.modelo} está ligando...")
    
    def __str__(self):
        # Podemos colocar dentro das "" o nome da classe e trazer os valores dos parâmetros:
        return f"Celular: {self.marca}, {self.modelo}"

# %%
# instancio o objeto:
meu_celular_2 = Celular("Motorola", "SX")

# %%
# análiso os seus valores por causa do método __str__():
print(meu_celular_2)
# Out:
# Celular: Motorola, SX

# %% [markdown]
# # Existe outra forma de fazer isso? Sim...
#
# Utilizaremos o mesmo método _ _str_ _(), mas dessa vez, ao invés de trazermos 'na mão' os valores, vamos utilizar juntos os métodos _ _class_ _ e _ _name_ _ e outros, da seguinte maneira:

# %%
class Livro:
    def __init__(self, nome_livro, autor):
        self.nome = nome_livro
        self.autor = autor
        # self.ano = ano
        # self.edicao = edicao

    def apresentar(self):
        print(f"Obrigado por adquirir o livro '{self.nome}'. Aqui você vai aprender a realmente como ler e aprender")

    
    def __str__(self):
    #     # Podemos colocar dentro das "" o nome da classe e trazer os valores dos parâmetros:
    # Utilizando 'list comprehenison'
         return f"{__class__.__name__}; {[", ".join(f"({chave}= {valor}" for chave, valor in self.__dict__.items())]}"

# %%
# análiso os seus valores por causa do método __str__():
livro_1 = Livro("Didascalicon", "Hugo de São Vitor")
livro_1.apresentar()
# Out:
# Obrigado por adquirir o livro 'Didascalicon'. Aqui você vai aprender a realmente como ler e aprender

# %%
# Por conta do __str__(), podemos retornar o nome com elementos 'classe.nome' utilizando __class__.__name__
print(livro_1)
# Out:
# Livro; ['(nome= Didascalicon, (autor= Hugo de São Vitor']
